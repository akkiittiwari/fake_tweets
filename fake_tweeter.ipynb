# %%
import pandas as pd
import numpy as np

import re
from textblob import TextBlob
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS as stopwords 
from nltk.corpus import stopwords
stop = stopwords.words('english')

import warnings
import pickle
warnings.filterwarnings('ignore')

# %%
data_path = './data/'

# %% [markdown]
# ## Reading the Data

# %%
tweets = pd.read_csv(data_path+'tweets.csv')
tweets
# Out:
#              user_id         user_key    created_at          created_str  \
# 0       2.532612e+09        kathiemrr  1.488207e+12  2017-02-27 14:54:00
# 1       2.531160e+09   traceyhappymom  1.471273e+12  2016-08-15 14:50:20
# 2                NaN    evewebster373  1.435701e+12  2015-06-30 21:56:09
# 3       4.840552e+09      blacktolive  1.474013e+12  2016-09-16 08:04:48
# 4       1.694026e+09  jacquelinisbest  1.474228e+12  2016-09-18 19:46:25
# 5       2.587101e+09   judelambertusa  1.460029e+12  2016-04-07 11:37:45
# 6       1.647046e+09  carriethornthon  1.476133e+12  2016-10-10 21:04:06
# 7       1.657754e+09      johnbranchh  1.447286e+12  2015-11-11 23:54:42
# 8       7.374200e+17  march_for_trump  1.475376e+12  2016-10-02 02:35:35
# 9       2.620870e+09        puredavie  1.482331e+12  2016-12-21 14:35:32
# 10      1.657695e+09      daileyjadon  1.479726e+12  2016-11-21 11:04:00
# 11      2.533654e+09       evagreen69  1.484879e+12  2017-01-20 02:16:36
# ...

# %%
users = pd.read_csv(data_path+'users.csv')
users
# Out:
#                id                       location                 name  \
# 0    1.003451e+08  still ⬆️Block⤵️Corner⬇️street     #Ezekiel2517✨...
# 1    2.471657e+08                    Chicago, IL     B E C K S T E R✨
# 2    2.495389e+08                            NaN        Chris Osborne
# 3    4.496897e+08                            NaN       Рамзан Кадыров
# 4    4.718689e+08        Санкт-Петербург, Россия      Маргарита Саваж
# 5    1.039581e+09                        Amerika           Dark Nally
# 6    1.510489e+09                            USA          Laila Heats
# 7    1.513801e+09                            USA              CC Jack
# 8    1.517679e+09               Philadelphia, PA             Mr Moran
# 9    1.518857e+09                            USA     Jonathon Norwood
# 10   1.532864e+09                            ATL           Harper H21
# 11   1.533814e+09                            USA          Lara Pretty
# ...

# %%
tweets.text[1]
# Out:
# 'RT @mc_derpin: #TheOlderWeGet the more pessimistic we are https://t.co/zS3jHZJl8P'

# %% [markdown]
# ## Merging Users and Tweets + Removing nulls

# %%
merged_data = tweets.merge(users, how='left', left_on='user_id', right_on='id')
merged_data = merged_data[pd.notnull(merged_data['user_id'])]
merged_data = merged_data[pd.notnull(merged_data['text'])]
merged_data.isnull().sum()
# Out:
# user_id                       0
# user_key                      0
# created_at_x                  0
# created_str                   0
# retweet_count            137313
# retweeted                137313
# favorite_count           137313
# text                          0
# tweet_id                   2172
# source                   137313
# hashtags                      0
# expanded_urls                 0
# posted                        0
# mentions                      0
# retweeted_status_id      155768
# in_reply_to_status_id    194806
# id                            0
# location                  29975
# name                       9767
# followers_count            9767
# statuses_count             9767
# time_zone                 10236
# verified                   9767
# lang                       9767
# screen_name                   0
# description               21622
# created_at_y               9767
# favourites_count           9767
# friends_count              9767
# ...

# %%
# saving original copy of this df for later reference
org_merged_data = merged_data.copy()
org_merged_data.to_pickle('merged_data')

# %% [markdown]
# ## Cleaning

# %%
#get rid of special characters
tweetsonly = merged_data.text.copy().astype(str)
tweetsonly = tweetsonly.str.replace('[^\w\s]','')
tweetsonly = tweetsonly.str.replace('[\\r|\\n|\\t|_]',' ')
tweetsonly = tweetsonly.str.strip()
tweetsonly = [re.sub(r'[^a-zA-Z ]+', '', tweet) for tweet in tweetsonly]


merged_data.text = tweetsonly
stop += ['rt']
merged_data.text = merged_data.text.apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in (stop)]))
merged_data.text = merged_data.text.apply(lambda x: ' '.join([word.lower() for word in x.split() if len(word) > 2]))

# %% [markdown]
# ## Exploratory analysis of tweets

# %%
## Create a sentiment column
def analyze_sentiment(tweet, senti_type='polarity'):
    '''
    Utility function to classify the sentiment of a tweet
    using textblob.
    '''
    analysis = TextBlob(tweet)
    if senti_type=='polarity':
        return analysis.sentiment.polarity
    else :
        return analysis.sentiment.subjectivity

# %%
# create sentiment and subjectivity columns

merged_data['Sentiment'] = np.array([analyze_sentiment(str(tweet)) for tweet in merged_data.text.values])
merged_data['Subjectivity'] = np.array([analyze_sentiment(str(tweet), 'subjectivity') for tweet in merged_data.text.values])

# %%
merged_data.head()
# Out:
#          user_id         user_key  created_at_x          created_str  \
# 0   2.532612e+09        kathiemrr  1.488207e+12  2017-02-27 14:54:00
# 1   2.531160e+09   traceyhappymom  1.471273e+12  2016-08-15 14:50:20
# 63  4.840552e+09      blacktolive  1.474013e+12  2016-09-16 08:04:48
# 64  1.694026e+09  jacquelinisbest  1.474228e+12  2016-09-18 19:46:25
# 65  2.587101e+09   judelambertusa  1.460029e+12  2016-04-07 11:37:45
#
#     retweet_count retweeted  favorite_count  \
# 0             NaN       NaN             NaN
# 1             NaN       NaN             NaN
# 63           18.0     False            17.0
# 64            0.0     False             0.0
# 65            NaN       NaN             NaN
#
#                                                  text      tweet_id  \
# 0             thingsdonebymistake kissing auntie lips  8.362279e+17
# 1   derpin theolderweget pessimistic httpstcozsjhzjlp  7.651989e+17
# 63           amen blacklivesmatter httpstcowgffaoqgzl  7.766933e+17
# ...

# %%
from matplotlib import pyplot as plt
from plotly.offline import init_notebook_mode, iplot
from IPython.display import display, HTML
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Create traces
trace0 = go.Scatter(
    x = merged_data.Sentiment.value_counts().reset_index()['index'],
    y = merged_data.Sentiment.value_counts().reset_index()['Sentiment'],
    mode = 'markers',
    name = 'Subjectivity'
)
trace1 = go.Scatter(
    x = merged_data.Subjectivity.value_counts().reset_index()['index'],
    y = merged_data.Subjectivity.value_counts().reset_index()['Subjectivity'],
    mode = 'markers',
    name = 'Sentiment'
)

layout = go.Layout(
    title='Sentiment Analysis of fake tweets',
    xaxis=dict(
        title='Sentiment/Subjectivity score',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='Count',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        ),
        range = [0, 10000]
    )
)

data_plot = [trace0, trace1]
fig = go.Figure(data=data_plot, layout=layout)
iplot(fig, filename='scatter-mode')
# Out:
# <div id="8c19ab30-bdb1-4dd3-941c-906091b7191b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8c19ab30-bdb1-4dd3-941c-906091b7191b", [{"type": "scatter", "x": [0.0, 0.5, 0.2, -0.5, 0.25, 0.1, 0.8, 0.13636363636363635, -0.2, 0.4, -0.4, -0.1, -0.16666666666666666, 0.3, 0.35, 0.7, -0.25, 1.0, -0.6, -0.3, 0.6, -1.0, 0.2857142857142857, -0.05, -0.8, 0.05, -0.125, 0.06818181818181818, 0.375, 0.16666666666666666, 0.3333333333333333, -0.15, 0.125, 0.15, -0.08333333333333333, -0.3333333333333333, -0.6999999999999998, -0.1875, -0.15000000000000002, 0.15000000000000002, -0.3125, 0.45, 0.4000000000000001, 0.16, 0.03333333333333333, 0.10000000000000002, -0.7, 0.55, -0.2916666666666667, 0.4166666666666667, 0.6000000000000001, 0.175, 0.65, -0.13333333333333333, 0.14285714285714285, 0.04999999999999999, 0.2666666
# ...

# %%
#LDA
import pyLDAvis
import pyLDAvis.gensim
from nltk.corpus import stopwords
stop = stopwords.words('english')
pyLDAvis.enable_notebook()
from gensim import corpora, models
import gensim
# Out:
# /usr/local/lib/python3.6/site-packages/scipy/sparse/sparsetools.py:20: DeprecationWarning:
#
# `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.

# %%
# compile sample documents into a list
doc_set = merged_data.text.values.copy()
# loop through document list
texts = [text.split(' ') for text in doc_set]
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]
# generate LDA model
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=30, id2word = dictionary)

# %%
data = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
data
# Out:
# PreparedData(topic_coordinates=           Freq  cluster  topics         x         y
# topic
# 20     6.210690        1       1  0.289572 -0.060162
# 15     5.212059        1       2  0.008411  0.307944
# 4      4.335407        1       3  0.250390 -0.036724
# 6      3.747123        1       4 -0.020945  0.231301
# 29     3.734317        1       5  0.117296  0.036820
# 17     3.533534        1       6  0.101783  0.039624
# 28     3.530652        1       7  0.059780  0.042743
# 26     3.514915        1       8  0.090050 -0.097271
# 21     3.325716        1       9  0.109698  0.001695
# 22     3.220973        1      10 -0.051335  0.025379
# 14     3.205156        1      11  0.039770  0.008553
# 7      3.100322        1      12 -0.056811 -0.058491
# 23     3.094395        1      13  0.019546 -0.041079
# 19     3.084883        1      14 -0.070398 -0.009803
# 12     3.060898        1      15  0.053875 -0.050932
# 9      3.055994        1      16 -0.065071 -0.008667
# ...

# %%
from scipy import stats

#create a line of best fit
slope, intercept, r_value, p_value, std_err = stats.linregress(users.followers_count,users.statuses_count)
line = slope*users.followers_count+intercept

# %%
trace = go.Scatter(
    x = users.followers_count,
    y = users.statuses_count,
    mode = 'markers',
    text = users.name,
    marker = dict(size = 10,
        color = 'blue',
        line = dict(
            width = 2,
            color = 'rgb(0, 0, 0)'
        ))
)

trace2 = go.Scatter(
                  x=users.followers_count,
                  y=line,
                  mode='lines',
                  marker=go.Marker(color='black'),
                  name='Fit'
                  )

data = [trace, trace2]

layout = go.Layout(
    title = "Russian Fake Account Followers and Tweet Count",
    xaxis=dict(
            title='Number of Followers',
            dtick=10000,
            range=[0, 100000],
            titlefont=dict(
            size=20,
        )
    ),
   
    yaxis = dict(
        title='Number of Tweets',
        range=[0, 70000],
        titlefont=dict(
            size=20,
        )
    ),
    
    annotations=[dict(y=20576,x=61609,xref='x',
            yref='y',text='Jenna Abrams'),
                dict(y=42438,x=60897,xref='x',
            yref='y',text='New York City Today'),
                dict(y=44882,x=27745,xref='x',
            yref='y',text='New Orleans Online'),
                dict(x=98412,y=30624,xref='x',
            yref='y',text='Максим Дементьев'),
                dict(y=1370,x=11518,xref='x',
            yref='y',text='Black News'),
                dict(y=57212,x=11370,xref='x',
            yref='y',text='РИА ФАН'),
                dict(y=28939,x=31729,xref='x',
            yref='y',text='Washington Online')]
)
fig = go.Figure(data=data, layout=layout)
fig['layout'].update(height=900, width=1200, titlefont=dict(size=20))
iplot(fig)
# Out:
# <div id="fef76a4a-1e5b-4212-ba55-a953c2a72ab7" style="height: 900px; width: 1200px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fef76a4a-1e5b-4212-ba55-a953c2a72ab7", [{"type": "scatter", "x": [1053.0, 650.0, 44.0, 94773.0, 23305.0, 22.0, 3080.0, 2760.0, 879.0, 789.0, 1956.0, 1795.0, 728.0, 837.0, 738.0, 908.0, 877.0, 1565.0, 674.0, 2854.0, 2121.0, 2291.0, 853.0, 1519.0, 909.0, 1457.0, 2804.0, 456.0, 429.0, 900.0, 671.0, 905.0, 916.0, 963.0, 784.0, 3242.0, 1753.0, 1822.0, 1073.0, 1032.0, 826.0, null, null, null, null, 824.0, 865.0, 1588.0, 1578.0, 827.0, 2102.0, 820.0, 943.0, 3143.0, 2694.0, 841.0, 941.0, 2225.0, 873.0, 3356.0, 797.0, 1909.0, 1055.0, 2464.0, 683.0, 2608.0, 770.0, 904.0, 696.0, 541.0, 849.0, 2569.0, 13196.0, 851.0, 3229.0, 856.0, 766.0, 2078.0, 1506.0, 876.0, null, 899.0, 1468.0, 698.0, 536.0, 906.0, 1080.0, 1623
# ...

# %% [markdown]
# ## Which fake tweeter are you

# %%
from keras.preprocessing import sequence
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# check if 140 is correct length to cutoff at 
len([len(tweetsonly[i]) for i in range(len(tweetsonly)) if len(tweetsonly[i])> 140])
# Out:
# 84

# %% [markdown]
# - Encoding the User (response variable) using sklearn LabelEncoder

# %%
user_encoder = LabelEncoder()
merged_data['user_id_encoded'] = user_encoder.fit_transform(merged_data.user_id)
merged_data.user_id_encoded.head()
# Out:
# 0     192
# 1     189
# 63    352
# 64    113
# 65    260
# Name: user_id_encoded, dtype: int64

# %%
pickle.dump(user_encoder, open('user_encoder', 'wb'))

# %%
x_y = pd.DataFrame({'X': tweetsonly, 'Y':merged_data['user_id_encoded']})
print(x_y.shape)
x_y = x_y.loc[x_y.X.apply(len)>0].reset_index(drop=True)
print(x_y.shape)
# Out:
# (195365, 2)
# (195358, 2)

# %%
len(x_y.Y.unique())
# Out:
# 371

# %% [markdown]
# - Trying to fit a logistic regression classifier using bag of words approach [tdfidf score and countvectorizer]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000)

tfv = TfidfVectorizer(min_df=3, max_features=None,
                          strip_accents='unicode', analyzer='word',
                          token_pattern=r'\w{1,}',
                          ngram_range=(1, 2), use_idf=1, smooth_idf=1,
                          sublinear_tf=1,
                          stop_words='english')

# %%
# x_train_features = vectorizer.fit_transform(x_train)
# x_train_features

tfv.fit(x_y.X)
x_y_features = tfv.transform(x_y.X)

# %%
# x_train, x_test, y_train, y_test = train_test_split(x_y.features, x_y.Y, test_size=0.33, random_state=42)
train_len = int(len(x_y)*0.7)
x_train = x_y_features[:train_len]
y_train = x_y.Y[:train_len]
x_test = x_y_features[train_len:]
y_test = x_y.Y[train_len:]

# %%
# Initialize a Logistic Regression
lr = LogisticRegression(penalty='l2', n_jobs=-1)

lr = lr.fit(x_train, y_train)

# %%
result = lr.predict(x_test)
accuracy_score(y_test, result)
# Out:
# 0.22664141414141414

# %% [markdown]
# ## Trying glove encoding : taking centroid of each tweet and taking it as features

# %%
from textblob import TextBlob

# %%
def load_glove(filename):
    """
    Read all lines from the indicated file and return a dictionary
    mapping word:vector where vectors are of numpy `array` type.
    GloVe file lines are of the form:

    the 0.418 0.24968 -0.41242 0.1217 ...

    So split each line on spaces into a list; the first element is the word
    and the remaining elements represent factor components. The length of the vector
    should not matter; read vectors of any length.
    """
    f = open(filename, 'r')
    word_dict = dict()
    for line in f:
        word_list = line.split()
        word_dict[word_list[0]] = np.array(word_list[1:])
        word_dict[word_list[0]] = word_dict[word_list[0]].astype(np.float)
    return word_dict

# %%
def tweet2vec(text):
    """
    Return the word vector centroid for the text. Sum the word vectors
    for each word and then divide by the number of words. Ignore words
    not in gloves.
    """
    centroid = []
    count = 0
    words_list = TextBlob(text).tokens
    for word in words_list:
        if word in gloves:
            centroid.append(np.array(gloves[word]))
            count = count + 1
    centroid = np.sum(centroid, axis=0) / count
    return centroid

# %%
gloves = load_glove('./data/glove.6B.50d.txt')

# %%
x_y['encoded_features'] = x_y.X.apply(lambda x : tweet2vec(x))

# %%
x_y.dropna(axis=0, inplace=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_y.encoded_features, x_y.Y, test_size=0.33, random_state=42)
# train_len = int(len(x_y)*0.7)
# x_train = x_y.encoded_features[:train_len]
# y_train = x_y.Y[:train_len]
# x_test = x_y.encoded_features[train_len:]
# y_test = x_y.Y[train_len:]

# %%
train_len = len(x_train)
x_train = np.array([val for sublist in (x_train.apply(lambda x : x.flatten())).values for val in sublist]).reshape(train_len,50)
test_len = len(x_test)
x_test = np.array([val for sublist in (x_test.apply(lambda x : x.flatten())).values for val in sublist]).reshape(test_len,50)
print(train_len, test_len)
print (x_train.shape, x_test.shape)
# Out:
# 115917 57094
# (115917, 50) (57094, 50)

# %% [markdown]
# - trying logistic regression with glove encoding centroids

# %%
# Initialize a Logistic Regression
print('Fitting lr...')
lr = LogisticRegression(penalty='l2', n_jobs=-1)

lr = lr.fit(list(x_train), list(y_train))
# Out:
# Fitting lr...

# %%
pickle.dump(lr, open('lr_model_50enc', 'wb'))
result = lr.predict(x_test)
accuracy_score(y_test, result)
# Out:
# 0.07908011349703997

# %% [markdown]
# - Trying a simple MLP. But as the number of classes are high, a basic MLP won't perform much better

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
print('Building model...')

model = Sequential()

model.add(Dense(1000, input_shape=(50,))) 

# model.add(Dense(1000, activation='relu')) 
model.add(Dense(1000, activation='relu'))
# model.add(Dense(500, activation='relu'))
model.add(Dense(367, activation='softmax')) 
# model.add(Activation('softmax'))
# Out:
# Building model...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_43 (Dense)             (None, 1000)              51000
# _________________________________________________________________
# dense_44 (Dense)             (None, 1000)              1001000
# _________________________________________________________________
# dense_45 (Dense)             (None, 367)               367367
# ...
# Total params: 1,419,367
# Trainable params: 1,419,367
# Non-trainable params: 0
# _________________________________________________________________

# %%
print (len(y_train.unique()))
print (len(y_test.unique()))
# Out:
# 367
# 326

# %%
print("Training model...")

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

batch_size = 32
epochs = 2

history = model.fit(x_train, np.array(y_train),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=True,
                    validation_split=0.1)
# Out:
# Training model...

# %%
loss, accuracy = model.evaluate(list(x_test), list(y_test),
                                batch_size=batch_size, 
                                verbose=True)

print(f'Test Loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')

# %% [markdown]
# - MLP is taking too much time to tune and train. We can try something simpler which makes more sense in this problem to

# %% [markdown]
# - Classifying using KNN with K=7

# %%
from sklearn.neighbors import KNeighborsClassifier

train_len = len(x_y.encoded_features)
x = np.array([val for sublist in (x_y.encoded_features.apply(lambda x : x.flatten())).values for val in sublist]).reshape(train_len,50)
y = np.array(x_y.Y)

knn = KNeighborsClassifier(n_neighbors=7, n_jobs=-1)
knn.fit(x, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=7, p=2,
#            weights='uniform')

# %%
pickle.dump(knn, open('knn_model_50enc', 'wb'))

# %% [markdown]
# ## Prediction on new text

# %%
sample_input = """"North Korean Leader Kim Jong Un just stated that the 'Nuclear Button is on his desk at all times,' Will someone from his depleted and food starved regime please inform him that I too have a Nuclear Button, but it is a much bigger & more powerful one than his, and my Button works! Donald Trump"""

# %%
#get rid of special characters
def tokenize_input(inp):
    inp = inp.replace('[^\w\s]','')
    inp = inp.replace('[\\r|\\n|\\t|_]',' ')
    inp = inp.strip()
    inp = re.sub(r'[^a-zA-Z ]+', '', inp)
    inp = ' '.join([word for word in inp.split() if word.lower() not in (stop) and len(word)>2])
    return inp

# %%
inp = tokenize_input(sample_input)
inp_centroid = tweet2vec(inp)

# %%
predicted_user = knn.predict(np.array(inp_centroid).reshape(1, -1).astype(np.float))
predicted_user_id = user_encoder.inverse_transform(predicted_user)

# %%
filtered_result = org_merged_data[org_merged_data.user_id==predicted_user_id[0]].reset_index(drop=True)

# %%
filtered_result.iloc[0]
# Out:
# user_id                                                        1.67928e+09
# user_key                                                     ameliebaldwin
# created_at_x                                                   1.47414e+12
# created_str                                            2016-09-17 20:09:42
# retweet_count                                                            0
# retweeted                                                            False
# favorite_count                                                           0
# text                     RT @American_Woman4: #MAGA,#FEMININEAMERICA4TR...
# tweet_id                                                       7.77238e+17
# source                   <a href="http://twitter.com" rel="nofollow">Tw...
# hashtags                 ["FEMININEAMERICA4TRUMP","maga","FL4Trump","LG...
# expanded_urls            ["https://twitter.com/Harlan/status/7771458096...
# ...

# %%
# [item for sublist in filtered_result.hashtags.values for item in sublist]
from collections import Counter

tokens = list(TextBlob(re.sub(r'[^a-zA-Z ]+', '', ' '.join(filtered_result.hashtags.values))).tokens)
c = Counter(tokens)

# %%
print([x[0] for x in c.most_common(5)])
# Out:
# ['Trump', 'maga', 'NeverHillary', 'tcot', 'MakeAmericaGreatAgain']

# %%
print('''Here is your Fake Tweeter avatar ::


Your Screen Name : %s,
Your Fake Tweeter alias : %s,
Description : %s,
Number of Friends : %s,
Location : %s,
Most used Hashtags : %s,
Most Retweeted Tweets : 
'''%(filtered_result.screen_name[0], filtered_result.name[0], filtered_result.description[0], 
     filtered_result.friends_count[0], filtered_result.location[0], [x[0] for x in c.most_common(5)]))
[print('- ', a) for a in filtered_result.nlargest(5, 'retweet_count').text.values]
# Out:
# Here is your Fake Tweeter avatar ::
#
#
# Your Screen Name : AmelieBaldwin,
# Your Fake Tweeter alias : Amelie Baldwin,
# Description : Wife, Mother, Patriot, Friend,
# Number of Friends : 1930.0,
# Location : USA,
# Most used Hashtags : ['Trump', 'maga', 'NeverHillary', 'tcot', 'MakeAmericaGreatAgain'],
# Most Retweeted Tweets :
#
# -  It's either working class "kills" her, or she kills working class
# So make your choice!!!! #tcot https://t.co/LkLqJIT1o6
# -  We need to bring our country back from the edge of extinction!!! @realDonaldTrump #WakeUpAmerica https://t.co/bDnzjDya0R
# -  You'd better read it before watching #debates
# https://t.co/wPo3W6sVU5
# -  First time ever voting in 38 Years! #ElectionDay #TrumpWinsBecause #TrumpPence16 . I BELIEVE ♡ #TrumpForPresident
# -  CALLING ON ALL #TRUMP_VOTERS  URGENT‼️ #TrumpPence16  #TrumpForPresident  #PodestaEmails33  PLEASE RT RT RT ‼️ https://t… #TrumpForPresident
# [None, None, None, None, None]
